# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ks_df = pd.read_csv("results/Hopf_ks_data.csv", index_col=0)
shorthand = "Hopf"
ks_df
# Out:
#        Param   Method     KS
# 1         kA      SMC  0.036
# 2         kA      SMC  0.045
# 3         kA      SMC  0.024
# 4         kA      SMC  0.027
# 5         kA      SMC  0.044
# ...      ...      ...    ...
# 89994  dummy  PT-MCMC  0.032
# 89995  dummy  PT-MCMC  0.025
# 89996  dummy  PT-MCMC  0.038
# 89997  dummy  PT-MCMC  0.033
# 89998  dummy  PT-MCMC  0.038
#
# [89100 rows x 3 columns]

# %%
plt.figure(figsize=(6,4), dpi=350)
sns.boxplot(data=ks_df, x="Param", hue="Method", y="KS", showfliers=True, legend=False)
#plt.xticks(rotation=90);
plt.ylabel("Two-Way Kolmogorov-Smirnov Statistic")
plt.title(shorthand)
plt.axhline(y=0.05, linestyle="--", color="r", lw=2);
