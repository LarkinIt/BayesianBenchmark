# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ks_df = pd.read_csv("results/linear_mRNA_self_reg_ks_data.csv", index_col=0)
shorthand = "mRNA"
ks_df
# Out:
#          Param   Method     KS
# 1       param0      SMC  0.055
# 2       param0      SMC  0.035
# 3       param0      SMC  0.051
# 4       param0      SMC  0.055
# 5       param0      SMC  0.025
# ...        ...      ...    ...
# 149994   dummy  PT-MCMC  0.063
# 149995   dummy  PT-MCMC  0.036
# 149996   dummy  PT-MCMC  0.028
# 149997   dummy  PT-MCMC  0.038
# 149998   dummy  PT-MCMC  0.030
#
# [148500 rows x 3 columns]

# %%
plt.figure(figsize=(10,4.5), dpi=350)
sns.boxplot(data=ks_df, x="Param", hue="Method", y="KS", showfliers=True)
#plt.xticks(rotation=90);
plt.ylabel("Two-Way Kolmogorov-Smirnov Statistic")
plt.title(shorthand)
plt.axhline(y=0.05, linestyle="--", color="r", lw=2);
