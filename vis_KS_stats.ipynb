# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ks_df = pd.read_csv("Shp2_ks_data.csv", index_col=0)
ks_df
# Out:
#         Param Method     KS
# 1        kdim    SMC  0.032
# 2        kdim    SMC  0.031
# 3        kdim    SMC  0.038
# 4        kdim    SMC  0.032
# 5        kdim    SMC  0.030
# ...       ...    ...    ...
# 499994  dummy    PMC  0.043
# 499995  dummy    PMC  0.024
# 499996  dummy    PMC  0.032
# 499997  dummy    PMC  0.024
# 499998  dummy    PMC  0.021
#
# [495000 rows x 3 columns]

# %%
plt.figure(figsize=(16,7), dpi=200)
sns.boxplot(data=ks_df, x="Param", hue="Method", y="KS", showfliers=True)
plt.xticks(rotation=90);
plt.ylabel("Two-Way Kolmogorov-Smirnov Statistic")
plt.axhline(y=0.05, linestyle="--", color="r", lw=2);
