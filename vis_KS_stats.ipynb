# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ks_df = pd.read_csv("Calcium_Oscillate_ks_data.csv", index_col=0)
ks_df
# Out:
#         Param   Method     KS
# 1          k1      SMC  0.549
# 2          k1      SMC  0.250
# 3          k1      SMC  0.996
# 4          k1      SMC  0.327
# 5          k1      SMC  0.996
# ...       ...      ...    ...
# 461370  dummy  PT-MCMC  1.000
# 461371  dummy  PT-MCMC  1.000
# 461372  dummy  PT-MCMC  1.000
# 461373  dummy  PT-MCMC  1.000
# 461374  dummy  PT-MCMC  1.000
#
# [456672 rows x 3 columns]

# %%
plt.figure(figsize=(16,8), dpi=200)
sns.boxplot(data=ks_df, x="Param", hue="Method", y="KS", showfliers=False)
# Out:
# <Axes: xlabel='Param', ylabel='KS'>
